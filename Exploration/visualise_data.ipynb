# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 

path_dir = '/Volumes/DISQUE_Tit/PROJECTS/Coughvid-COVID-Predictor/'

path_img_dir_train = path_dir + "Data/MelSpecs_train"
df_label_train = pd.read_csv(path_dir + "Data/MelSpecs_labels_train.csv")

# %%
df_label_train
# Out:
#         filename  label
# 0          0.png      1
# 1          1.png      1
# 2          2.png      1
# 3          3.png      1
# 4          4.png      1
# ...          ...    ...
# 61895  61895.png      0
# 61896  61896.png      0
# 61897  61897.png      0
# 61898  61898.png      0
# 61899  61899.png      0
#
# [61900 rows x 2 columns]

# %% [markdown]
# Sick patient

# %%
img_path = os.path.join(path_img_dir_train, df_label_train.iloc[0]["filename"])

im = plt.imread(img_path)
plt.imshow(im)
plt.axis('off')
plt.show()

# %%
img_path = os.path.join(path_img_dir_train, df_label_train.iloc[1]["filename"])

im = plt.imread(img_path)
plt.imshow(im)
plt.axis('off')
plt.show()

# %%
img_path = os.path.join(path_img_dir_train, df_label_train.iloc[2]["filename"])

im = plt.imread(img_path)
plt.imshow(im)
plt.axis('off')
plt.show()

# %% [markdown]
# Healthy patient

# %%
img_path = os.path.join(path_img_dir_train, df_label_train.iloc[61896]["filename"])

im = plt.imread(img_path)
plt.imshow(im)
plt.axis('off') 
plt.show()

# %%
img_path = os.path.join(path_img_dir_train, df_label_train.iloc[61897]["filename"])

im = plt.imread(img_path)
plt.imshow(im)
plt.axis('off') 
plt.show()
